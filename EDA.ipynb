# %% [markdown]
# ## Importar bibliotecas

# %%
import pandas as pd
import numpy as np
import unicodedata
import re
from unicodedata import normalize

# %% [markdown]
# ## Cargar los archivos csv y json a Data Frames

# %% [markdown]
# Cargamos a los datasets en Data Frames y verificamos la información que estos contienen

# %%
amazon = pd.read_csv('Datasets/amazon_prime_titles.csv')
print(amazon.info())
amazon.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB
# None
#   show_id   type                 title      director  \
# 0      s1  Movie   The Grand Seduction  Don McKellar
# 1      s2  Movie  Take Care Good Night  Girish Joshi
#
# ...

# %%
disney = pd.read_csv('Datasets/disney_plus_titles.csv')
print(disney.info())
disney.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1450 non-null   object
#  1   type          1450 non-null   object
#  2   title         1450 non-null   object
#  3   director      977 non-null    object
#  4   cast          1260 non-null   object
#  5   country       1231 non-null   object
#  6   date_added    1447 non-null   object
#  7   release_year  1450 non-null   int64
#  8   rating        1447 non-null   object
#  9   duration      1450 non-null   object
#  10  listed_in     1450 non-null   object
#  11  description   1450 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 136.1+ KB
# None
#   show_id   type                                             title  \
# 0      s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2  Movie                            Ernest Saves Christmas
# ...

# %%
hulu = pd.read_csv('Datasets/hulu_titles.csv')
print(hulu.info())
hulu.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3073 non-null   object
#  1   type          3073 non-null   object
#  2   title         3073 non-null   object
#  3   director      3 non-null      object
#  4   cast          0 non-null      float64
#  5   country       1620 non-null   object
#  6   date_added    3045 non-null   object
#  7   release_year  3073 non-null   int64
#  8   rating        2553 non-null   object
#  9   duration      2594 non-null   object
#  10  listed_in     3073 non-null   object
#  11  description   3069 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 288.2+ KB
# None
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# ...

# %%
netflix = pd.read_json('Datasets/netflix_titles.json')
print(netflix.info())
netflix.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB
# None
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water             None
#
# ...

# %% [markdown]
# ## Verificamos si hay registros duplicados

# %%
amazon[amazon.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
disney[disney.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
hulu[hulu.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
netflix[netflix.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# ## Verificar valores unicos en columnas de interes

# %% [markdown]
# ### Amazon

# %%
amazon['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
amazon['director'].unique()
# Out:
# array(['Don McKellar', 'Girish Joshi', 'Josh Webber', ...,
#        'John-Paul Davidson, Stephen Warbeck', 'Emily Skye',
#        'Steve Barker'], dtype=object)

# %%
amazon['release_year'].unique()
# Out:
# array([2014, 2018, 2017, 1989, 2016, 1994, 2020, 2019, 2008, 2001, 1941,
#        1991, 2005, 2015, 2011, 2013, 1949, 2007, 2002, 1955, 1959, 1983,
#        2009, 2012, 2010, 1986, 1988, 1920, 1936, 1992, 2021, 1993, 2006,
#        1948, 1946, 1944, 1935, 1985, 1937, 1970, 1945, 1939, 1996, 1997,
#        1974, 1938, 1978, 2004, 1943, 1975, 1960, 1934, 1940, 1961, 2003,
#        2000, 1967, 1995, 1951, 1932, 1999, 1963, 1969, 1952, 1947, 1929,
#        1990, 1925, 1968, 1987, 1942, 1979, 1980, 1981, 1976, 1966, 1973,
#        1956, 1972, 1950, 1953, 1982, 1977, 1933, 1958, 1984, 1998, 1924,
#        1922, 1926, 1954, 1930, 1971, 1965, 1931, 1923, 1962, 1964, 1957,
#        1927], dtype=int64)

# %%
amazon['rating'].unique()
# Out:
# array([nan, '13+', 'ALL', '18+', 'R', 'TV-Y', 'TV-Y7', 'NR', '16+',
#        'TV-PG', '7+', 'TV-14', 'TV-NR', 'TV-G', 'PG-13', 'TV-MA', 'G',
#        'PG', 'NC-17', 'UNRATED', '16', 'AGES_16_', 'AGES_18_', 'ALL_AGES',
#        'NOT_RATE'], dtype=object)

# %%
amazon['listed_in'].unique()
# Out:
# array(['Comedy, Drama', 'Drama, International', 'Action, Drama, Suspense',
#        'Documentary', 'Drama, Fantasy', 'Fantasy, Kids',
#        'Documentary, Special Interest', 'Comedy',
#        'Action, Science Fiction, Suspense', 'Drama', 'Adventure, Kids',
#        'Horror, Suspense', 'Documentary, Sports',
#        'Horror, Science Fiction', 'Kids, Special Interest',
#        'Comedy, Talk Show and Variety', 'Science Fiction', 'Kids',
#        'Action, Anime, Comedy',
#        'Arts, Entertainment, and Culture, Comedy, Drama', 'TV Shows',
#        'Animation, Anime, Fantasy', 'Action, Adventure, Animation',
#        'Anime, Kids', 'Music Videos and Concerts', 'Drama, Suspense',
#        'Fitness, Special Interest',
#        'Faith and Spirituality, Special Interest', 'Special Interest',
#        'Fitness', 'Action, Military and War, Western',
#        'Arts, Entertainment, and Culture, Comedy, Talk Show and Variety',
#        'Action, Western', 'Documentary, Science Fiction',
# ...

# %% [markdown]
# ### Disney

# %%
disney['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
disney['director'].unique()
# Out:
# array(['Alonso Ramirez Ramos, Dave Wasson', 'John Cherry', 'Karen Disher',
#        'Hamish Hamilton', nan, 'Liz Garbus', 'Kirk R. Thatcher',
#        'John Gleim', 'Leslie Iwerks', 'McKenna Harris', 'Kevin Lima',
#        'Patrick Osborne', 'Chris Buck, Jennifer Lee', 'Lauren MacMullan',
#        'Dan Mazer', 'Jaume Collet-Serra', 'John Kahrs',
#        'Destin Daniel Cretton', 'Manjari Makijany',
#        'Nathan Greno, Byron Howard',
#        'Stevie Wermers-Skelton, Kevin Deters', 'Roger Allers',
#        'David Clair', 'David Silverman', 'Dean Wellins', 'Mike Mitchell',
#        'Brian Levant', 'Alex Zamm',
#        'Kevin Deters, Stevie Wermers-Skelton', 'Robert Vince',
#        'Matthew Vaughn', 'Niki Caro', 'Daniel Stern',
#        'Don Bluth, Gary Goldman', 'Jim Greayer', 'Ben Crichton',
#        'Jeff Gordon', 'Kirk Thatcher', 'Dave Hoffman', 'Cate Shortland',
#        'John Hoffman, Janet Tobias', 'Tim Hill', 'Walt Becker',
#        'Ken Cunningham', 'Robert Stromberg',
# ...

# %%
disney['release_year'].unique()
# Out:
# array([2016, 1988, 2011, 2021, 2015, 2019, 2008, 2020, 2007, 2013, 2018,
#        2014, 2012, 2006, 2010, 1996, 2009, 2017, 1993, 1994, 1998, 1989,
#        1997, 2005, 2000, 2004, 1987, 1985, 1967, 1973, 1991, 1956, 1995,
#        1984, 1974, 1959, 2003, 1976, 2001, 1990, 1992, 1952, 1955, 1977,
#        1957, 1999, 1948, 1964, 1969, 1942, 1950, 1951, 1953, 1949, 1940,
#        1946, 1954, 1936, 1944, 1935, 1939, 1975, 1978, 2002, 1971, 1961,
#        1962, 1981, 1932, 1938, 1941, 1986, 1947, 1937, 1966, 1943, 1934,
#        1980, 1960, 1983, 1972, 1982, 1979, 1928, 1965, 1970, 1963, 1933,
#        1945, 1968], dtype=int64)

# %%
disney['rating'].unique()
# Out:
# array(['TV-G', 'PG', 'TV-PG', nan, 'PG-13', 'TV-14', 'G', 'TV-Y7', 'TV-Y',
#        'TV-Y7-FV'], dtype=object)

# %%
disney['listed_in'].unique()
# Out:
# array(['Animation, Family', 'Comedy', 'Animation, Comedy, Family',
#        'Musical', 'Docuseries, Historical, Music',
#        'Biographical, Documentary', 'Action-Adventure, Superhero',
#        'Docuseries, Reality, Survival',
#        'Animals & Nature, Docuseries, Family', 'Comedy, Family, Musical',
#        'Documentary', 'Comedy, Family, Music', 'Documentary, Family',
#        'Action-Adventure, Animals & Nature, Docuseries',
#        'Animals & Nature', 'Animation', 'Animation, Kids',
#        'Comedy, Coming of Age, Drama', 'Comedy, Family, Fantasy',
#        'Animation, Comedy, Drama', 'Animation, Family, Fantasy',
#        'Action-Adventure, Animation, Comedy', 'Comedy, Family',
#        'Action-Adventure, Comedy, Family', 'Lifestyle', 'Movies',
#        'Action-Adventure, Science Fiction',
#        'Action-Adventure, Fantasy, Superhero', 'Coming of Age, Music',
#        'Animation, Drama', 'Concert Film, Music',
# ...

# %% [markdown]
# ### Hulu

# %%
hulu['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
hulu['director'].unique()
# Out:
# array([nan,
#        'Director Jennifer Kent ("The Babadook") tells the sweeping tale of a young woman\'s quest for revenge set in 1825 against the perilous and unforgiving terrain of Tasmania.',
#        'Director Gigi Saul Guerrero talks through Culture Shock’s themes – immigration, filmmaking, and latinidad – in this one-on-one chat.',
#        'Director Alex Winter goes inside the biggest global corruption scandal in history that was uncovered by hundreds of journalists, working in secret and at enormous risk.'],
#       dtype=object)

# %%
hulu['release_year'].unique()
# Out:
# array([2021, 2020, 2003, 2011, 2015, 2012, 2009, 2016, 2019, 2017, 2010,
#        2014, 2018, 2006, 2013, 1963, 1981, 1993, 2002, 1975, 2005, 2000,
#        2001, 1997, 1972, 1983, 1994, 2004, 1995, 1987, 1962, 1979, 1990,
#        1964, 1965, 1989, 1999, 1998, 1984, 1985, 2007, 1982, 1986, 1991,
#        1996, 1977, 1973, 2008, 1967, 1974, 1976, 1957, 1953, 1980, 1958,
#        1955, 1933, 1960, 1978, 1992, 1970, 1988, 1923, 1966, 1950, 1968,
#        1959, 1951, 1961, 1971, 1954, 1969], dtype=int64)

# %%
hulu['rating'].unique()
# Out:
# array(['TV-MA', nan, 'PG-13', 'R', 'TV-14', 'PG', 'TV-PG', 'NOT RATED',
#        'G', 'TV-G', '2 Seasons', 'TV-Y', '93 min', '4 Seasons', 'TV-Y7',
#        '136 min', '91 min', '85 min', '98 min', '89 min', '94 min',
#        '86 min', '3 Seasons', '121 min', '88 min', '101 min', '1 Season',
#        '83 min', '100 min', '95 min', '92 min', '96 min', '109 min',
#        '99 min', '75 min', '87 min', '67 min', '104 min', '107 min',
#        '84 min', '103 min', '105 min', '119 min', '114 min', '82 min',
#        '90 min', '130 min', '110 min', '80 min', '6 Seasons', '97 min',
#        '111 min', '81 min', '49 min', '45 min', '41 min', '73 min',
#        '40 min', '36 min', '39 min', '34 min', '47 min', '65 min',
#        '37 min', '78 min', '102 min', '129 min', '115 min', '112 min',
#        'NR', '61 min', '106 min', '76 min', '77 min', '79 min', '157 min',
#        '28 min', '64 min', '7 min', '5 min', '6 min', '127 min',
# ...

# %%
hulu['listed_in'].unique()
# Out:
# array(['Comedy, Stand Up', 'Crime, Drama, Thriller', 'Action, Thriller',
#        'Horror', 'Science Fiction, Thriller', 'Family, Kids',
#        'Horror, Thriller',
#        'Cooking & Food, Documentaries, Lifestyle & Culture',
#        'Drama, Music', 'Reality, Romance', 'Music, News', 'Comedy, Drama',
#        'News', 'Drama, Mystery', 'Reality', 'Sports',
#        'Documentaries, History', 'History, Reality',
#        'Documentaries, Reality, Teen', 'Thriller',
#        'Health & Wellness, Lifestyle & Culture, Reality',
#        'Black Stories, Reality', 'Documentaries, Reality, Romance',
#        'Documentaries, Drama, Mystery', 'Documentaries, Reality',
#        'Documentaries, News', 'Latino, Reality',
#        'Latino, Mystery, Science Fiction', 'Comedy, Latino',
#        'Documentaries, Sports', 'Action, Adventure, Comedy', 'Drama',
#        'Comedy', 'Documentaries', 'Crime, Documentaries',
#        'Action, Adventure, Anime', 'Action, Adventure', 'Anime',
# ...

# %% [markdown]
# ### Netflix

# %%
netflix['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
netflix['director'].unique()
# Out:
# array(['Kirsten Johnson', None, 'Julien Leclercq', ..., 'Majid Al Ansari',
#        'Peter Hewitt', 'Mozez Singh'], dtype=object)

# %%
netflix['release_year'].unique()
# Out:
# array([2020, 2021, 1993, 2018, 1996, 1998, 1997, 2010, 2013, 2017, 1975,
#        1978, 1983, 1987, 2012, 2001, 2014, 2002, 2003, 2004, 2011, 2008,
#        2009, 2007, 2005, 2006, 1994, 2015, 2019, 2016, 1982, 1989, 1990,
#        1991, 1999, 1986, 1992, 1984, 1980, 1961, 2000, 1995, 1985, 1976,
#        1959, 1988, 1981, 1972, 1964, 1945, 1954, 1979, 1958, 1956, 1963,
#        1970, 1973, 1925, 1974, 1960, 1966, 1971, 1962, 1969, 1977, 1967,
#        1968, 1965, 1946, 1942, 1955, 1944, 1947, 1943], dtype=int64)

# %%
netflix['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', None,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix['listed_in'].unique()
# Out:
# array(['Documentaries', 'International TV Shows, TV Dramas, TV Mysteries',
#        'Crime TV Shows, International TV Shows, TV Action & Adventure',
#        'Docuseries, Reality TV',
#        'International TV Shows, Romantic TV Shows, TV Comedies',
#        'TV Dramas, TV Horror, TV Mysteries', 'Children & Family Movies',
#        'Dramas, Independent Movies, International Movies',
#        'British TV Shows, Reality TV', 'Comedies, Dramas',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Dramas, International Movies',
#        'Children & Family Movies, Comedies',
#        'British TV Shows, Crime TV Shows, Docuseries',
#        'TV Comedies, TV Dramas', 'Documentaries, International Movies',
#        'Crime TV Shows, Spanish-Language TV Shows, TV Dramas',
#        'Thrillers',
#        'International TV Shows, Spanish-Language TV Shows, TV Action & Adventure',
#        'International TV Shows, TV Action & Adventure, TV Dramas',
# ...

# %% [markdown]
# ## Remplazamos los campos con valores nulos por "No Info"

# %%
amazon.cast.fillna('No Info', inplace=True)
disney.cast.fillna('No Info', inplace=True)
hulu.cast.fillna('No Info', inplace=True)
netflix.cast.fillna('No Info', inplace=True)

# %%
amazon.rating.fillna('No Info', inplace=True)
disney.rating.fillna('No Info', inplace=True)
hulu.rating.fillna('No Info', inplace=True)
netflix.rating.fillna('No Info', inplace=True)

# %%
amazon.duration.fillna('No Info', inplace=True)
disney.duration.fillna('No Info', inplace=True)
hulu.duration.fillna('No Info', inplace=True)
netflix.duration.fillna('No Info', inplace=True)

# %%
amazon.listed_in.fillna('No Info', inplace=True)
disney.listed_in.fillna('No Info', inplace=True)
hulu.listed_in.fillna('No Info', inplace=True)
netflix.listed_in.fillna('No Info', inplace=True)

# %% [markdown]
# ## Error en las columnas 'rating' y 'duration' del Data Frame "hulu"
#
# Algunos valores que deberian aparecer en la columna 'duration' aparecen en la columna 'rating',
# por lo que procedemos a corregir enta infonmación.

# %%
for i in range(hulu.shape[0]):
    aux = str(hulu['rating'].iloc[i])
    if hulu['duration'].iloc[i] == 'No Info':
        if (aux.split(' ')[-1] == 'min' or 
            aux.split(' ')[-1] == 'Seasons' or 
            aux.split(' ')[-1] == 'Season'):
            hulu['duration'].iloc[i] = aux
# Out:
# C:\Users\Hermann\Anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
hulu['duration'][hulu['duration'] == 'No Info'].count()
# Out:
# 187

# %% [markdown]
# ## Reemplazar valores faltantes
#
# Reemplazamos algunos valores nulos usando informacion de titulos que se
# repiten en 2 o mas data frames

# %%
def remplazar_cast(df1, df2):
    """
    Remplaza los valores de la columna 'cast' del data frama df1 que aparecen 
    como 'No Info' buscandolos en el data frame df2, esta busqueda se hace teniendo 
    en cuenta la columna 'title'
    """
    
    df1_null = df1[['title','release_year']][df1['cast'] == 'No Info']
    
    for index in  df1_null.index:
        if df2['title'].loc[(df2['title'] == df1_null['title'].loc[index])].shape[0] != 0:
            df1['cast'].loc[index] = df2['cast'].loc[df2['title'] == 
                                                     df1_null['title'].loc[index]].iloc[0]  
            
    return df1

# %% [markdown]
# Valores nulos antes de aplicar el reemplazo

# %%
print('amazon',amazon['cast'][amazon['cast'] == 'No Info'].count())
print('disney',disney['cast'][disney['cast'] == 'No Info'].count())
print('hulu',hulu['cast'][hulu['cast'] == 'No Info'].count())
print('netflix',netflix['cast'][netflix['cast'] == 'No Info'].count())
# Out:
# amazon 1233
# disney 190
# hulu 3073
# netflix 825

# %%
amazon = remplazar_cast(amazon, disney)
amazon = remplazar_cast(amazon, hulu)
amazon = remplazar_cast(amazon, netflix)

disney = remplazar_cast(disney, amazon)
disney = remplazar_cast(disney, hulu)
disney = remplazar_cast(disney, netflix)

hulu = remplazar_cast(hulu, amazon)
hulu = remplazar_cast(hulu, disney)
hulu = remplazar_cast(hulu, netflix)

netflix = remplazar_cast(netflix, amazon)
netflix = remplazar_cast(netflix, hulu)
netflix = remplazar_cast(netflix, disney)

# %% [markdown]
# Valores nulos depues de aplicar el reemplazo

# %%
print('amazon',amazon['cast'][amazon['cast'] == 'No Info'].count())
print('disney',disney['cast'][disney['cast'] == 'No Info'].count())
print('hulu',hulu['cast'][hulu['cast'] == 'No Info'].count())
print('netflix',netflix['cast'][netflix['cast'] == 'No Info'].count())
# Out:
# amazon 1211
# disney 188
# hulu 2666
# netflix 810

# %%
def remplazar_duration(df1, df2):
    """
    Remplaza los valores de la columna 'duration' del data frama df1 que aparecen 
    como 'No Info' buscandolos en el data frame df2, esta busqueda se hace teniendo 
    en cuenta la columna 'title'
    """
    
    df1_null = df1[['title','duration']][df1['duration'] == 'No Info']
    
    for index in  df1_null.index:
        if df2['title'].loc[(df2['title'] == df1_null['title'].loc[index])].shape[0] != 0:
            df1['duration'].loc[index] = df2['duration'].loc[df2['title'] == 
                                                             df1_null['title'].loc[index]].iloc[0]  
            
    return df1

# %% [markdown]
# Valores nulos antes de aplicar el reemplazo

# %%
print('amazon',amazon['duration'][amazon['duration'] == 'No Info'].count())
print('disney',disney['duration'][disney['duration'] == 'No Info'].count())
print('hulu',hulu['duration'][hulu['duration'] == 'No Info'].count())
print('netflix',netflix['duration'][netflix['duration'] == 'No Info'].count())
# Out:
# amazon 0
# disney 0
# hulu 187
# netflix 3

# %%
amazon = remplazar_duration(amazon, disney)
amazon = remplazar_duration(amazon, hulu)
amazon = remplazar_duration(amazon, netflix)

disney = remplazar_duration(disney, amazon)
disney = remplazar_duration(disney, hulu)
disney = remplazar_cast(disney, netflix)

hulu = remplazar_duration(hulu, amazon)
hulu = remplazar_duration(hulu, disney)
hulu = remplazar_duration(hulu, netflix)

netflix = remplazar_duration(netflix, amazon)
netflix = remplazar_duration(netflix, hulu)
netflix = remplazar_duration(netflix, disney)

# %% [markdown]
# Valores nulos despues de aplicar el reemplazo

# %%
print('amazon',amazon['duration'][amazon['duration'] == 'No Info'].count())
print('disney',disney['duration'][disney['duration'] == 'No Info'].count())
print('hulu',hulu['duration'][hulu['duration'] == 'No Info'].count())
print('netflix',netflix['duration'][netflix['duration'] == 'No Info'].count())
# Out:
# amazon 0
# disney 0
# hulu 178
# netflix 3

# %%
def remplazar_listed_in(df1, df2):
    """
    Remplaza los valores de la columna 'cast' del data frama df1 que aparecen 
    como 'No Info' buscandolos en el data frame df2, esta busqueda se hace teniendo 
    en cuenta la columna 'title'
    """
    
    df1_null = df1[['title','listed_in']][df1['listed_in'] == 'No Info']
    
    for index in  df1_null.index:
        if df2['title'].loc[(df2['title'] == df1_null['title'].loc[index])].shape[0] != 0:
            df1['listed_in'].loc[index] = df2['listed_in'].loc[df2['title'] == 
                                                               df1_null['title'].loc[index]].iloc[0]  
            
    return df1

# %% [markdown]
# Valores nulos antes de aplicar el reemplazo

# %%
print('amazon',amazon['listed_in'][amazon['listed_in'] == 'No Info'].count())
print('disney',disney['listed_in'][disney['listed_in'] == 'No Info'].count())
print('hulu',hulu['listed_in'][hulu['listed_in'] == 'No Info'].count())
print('netflix',netflix['listed_in'][netflix['listed_in'] == 'No Info'].count())
# Out:
# amazon 0
# disney 0
# hulu 0
# netflix 0

# %%
amazon = remplazar_listed_in(amazon, disney)
amazon = remplazar_listed_in(amazon, hulu)
amazon = remplazar_listed_in(amazon, netflix)

disney = remplazar_listed_in(disney, amazon)
disney = remplazar_listed_in(disney, hulu)
disney = remplazar_cast(disney, netflix)

hulu = remplazar_listed_in(hulu, amazon)
hulu = remplazar_listed_in(hulu, disney)
hulu = remplazar_listed_in(hulu, netflix)

netflix = remplazar_listed_in(netflix, amazon)
netflix = remplazar_listed_in(netflix, hulu)
netflix = remplazar_listed_in(netflix, disney)

# %% [markdown]
# Valores nulos despues de aplicar el reemplazo

# %%
print('amazon',amazon['listed_in'][amazon['listed_in'] == 'No Info'].count())
print('disney',disney['listed_in'][disney['listed_in'] == 'No Info'].count())
print('hulu',hulu['listed_in'][hulu['listed_in'] == 'No Info'].count())
print('netflix',netflix['listed_in'][netflix['listed_in'] == 'No Info'].count())
# Out:
# amazon 0
# disney 0
# hulu 0
# netflix 0

# %% [markdown]
# ## Concatenar los 4 data frames en uno solo llamado 'data'
#
# En este paso vamos a juntar los 4 data frames en uno solo,
# y agregamos la columna 'platform'.

# %%
amazon['platform'] = 'Amazon'
disney['platform'] = 'Disney'
hulu['platform'] = 'Hulu'
netflix['platform'] = 'Netflix'

data = pd.concat([amazon, disney, hulu, netflix])

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22998 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       22998 non-null  object
#  1   type          22998 non-null  object
#  2   title         22998 non-null  object
#  3   director      14739 non-null  object
#  4   cast          22998 non-null  object
#  5   country       11499 non-null  object
#  6   date_added    13444 non-null  object
#  7   release_year  22998 non-null  int64
#  8   rating        22998 non-null  object
#  9   duration      22998 non-null  object
#  10  listed_in     22998 non-null  object
#  11  description   22994 non-null  object
#  12  platform      22998 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 2.5+ MB

# %% [markdown]
# ## Eliminar columnas
#
# Eliminamos las columnas innecesarias para responder las preguntas de negocion que fueron planteadas

# %%
data.drop(['show_id','director','country','date_added','rating','description'], axis=1, inplace=True)
data
# Out:
#          type                 title  \
# 0       Movie   The Grand Seduction
# 1       Movie  Take Care Good Night
# 2       Movie  Secrets of Deception
# 3       Movie    Pink: Staying True
# 4       Movie         Monster Maker
# ...       ...                   ...
# 8802    Movie                Zodiac
# 8803  TV Show           Zombie Dumb
# 8804    Movie            Zombieland
# 8805    Movie                  Zoom
# 8806    Movie                Zubaan
#
#                                                    cast  release_year  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...          2017
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...          2014
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...          1989
# ...                                                 ...           ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22998 entries, 0 to 8806
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          22998 non-null  object
#  1   title         22998 non-null  object
#  2   cast          22998 non-null  object
#  3   release_year  22998 non-null  int64
#  4   duration      22998 non-null  object
#  5   listed_in     22998 non-null  object
#  6   platform      22998 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Crear tablas 'Platform' y 'Type'
#
# Creamos las tablas 'Platform' y 'Type' y las guardamos en archivos csv

# %%
Platform = pd.DataFrame({'IdPlatform':np.arange(1,len(data.platform.unique())+1), 
                         'Platform':data.platform.unique()})
Platform
# Out:
#    IdPlatform Platform
# 0           1   Amazon
# 1           2   Disney
# 2           3     Hulu
# 3           4  Netflix

# %%
Type = pd.DataFrame({'IdType': np.arange(1,len(data.type.unique())+1), 
                     'Type': data.type.unique()})
Type
# Out:
#    IdType     Type
# 0       1    Movie
# 1       2  TV Show

# %%
Platform.to_csv('./Tablas/Platform.csv', index=False, encoding='utf-8')

# %%
Type.to_csv('./Tablas/Type.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Cast

# %% [markdown]
# Reemplazamos los dobles y triples espacios por un solo espacio

# %%
# remplazamos triples espacios por un solo espacio
for i, item in enumerate(data.cast):
    if item.find('   ') != -1:
        data.cast.iloc[i] = item.replace('   ',' ')

# %%
# remplazamos los dobles espacios por un solo espacio
for i, item in enumerate(data.cast):
    if item.find('  ') != -1:
        data.cast.iloc[i] = item.replace('  ',' ')
# Out:
# C:\Users\Hermann\Anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# Registros que no incluyen comas

# %%
for item in data.cast:
    if item.find(',') == -1 and item != 'No Info':
        print(item)
# Out:
# Narrator - Gillian Barlett
# Zoë Coombs Marr
# Ann-Marie Newland
# Caroline Shola Arewa
# Anne-Marie Newland
# Dr Daniel J Nightingale
# Lindsey Samper
# Anne-Marie Newland
# Anne-Marie Newland
# Anne-Marie Newland
# Anne-Marie Newland
# Anne-Marie Newland
# Anne-Marie Newland
# Anne-Marie Newland
# Anne-Marie Newland
# Anne-Marie Newland
# Chuck Pell
# Bear Grylls
# Dan Aykroyd
# Liam Dale
# Tiffany Derry
# Anthony Mendez
# Michael Butt
# Jonathan Chase Cook
# William Lee Martin
# William Lee Martin
# Abish Mathew
# Neil Oliver
# Whitney Cummings
# Ashe Jaafaru
# John Daly
# John Young
# Shinba Tsuchiya | Ayane Sakura | Nobuhiko Okamoto | Kentaro Tomita | Sumire Morohoshi
# Peter Sallis
# Peter Sallis
# Stephen Noonan
# Kym Marsh
# Peter Sarsgaard
# Dawn Boldrin
# Zachary Levi
# Peter Miller
# JohnAnthonyWest.Dr.RobertM.Schoch
# Jim Nichols
# Peter Coyote
# William J. Birnes
# Otteson Family
# Adán Medrano
# Kevin Shelley
# various
# Geo Beach
# Richard Hammond
# Richard Hammond
# ...

# %% [markdown]
# Reemplazar registros con valor '1' por 'No Info'

# %%
data.cast.replace({'1': 'No Info'}, inplace=True)

# %% [markdown]
# Cadenas separadas por simbolos que no son comas

# %%
for item in data.cast:
    if item.find('/') != -1:
        print(item)
        
for item in data.cast:
    if item.find('|') != -1:
        print(item)
# Out:
# Sally Jing/ Jing Tian, Vin Zhang/Zhang Binbin
# Shinba Tsuchiya | Ayane Sakura | Nobuhiko Okamoto | Kentaro Tomita | Sumire Morohoshi

# %% [markdown]
# Reemplazar '/' y '|' por comas

# %%
for i, item in enumerate(data.cast):
    if item.find('/') != -1:
        data.cast.iloc[i] = item.replace('/',',')
        
for i, item in enumerate(data.cast):
    if item.find('|') != -1:
        data.cast.iloc[i] = item.replace('|',',')

# %% [markdown]
# Eliminar ', Jr.' y , Ph.D.

# %%
for i, item in enumerate(data.cast):
    if item.find(', Jr.') != -1:
        data.cast.iloc[i] = item.replace(', Jr.','')
        
for i, item in enumerate(data.cast):
    if item.find(', Ph.D.') != -1:
        data.cast.iloc[i] = item.replace(', Ph.D.','')

# %%
for item in data.cast:
    if item.find(', Jr.') != -1:
        print(item)

# %% [markdown]
# Eliminamos todo tipo de acentos

# %%
def eliminar_acentos(cad):
    s = cad
    # -> NFD y eliminar diacríticos
    s = re.sub(
        r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1", 
        normalize( "NFD", s), 0, re.I
    )

    # -> NFC
    s = normalize( 'NFC', s)
    return s

# %%
for i, item in enumerate(data.cast):
    data.cast.iloc[i] = eliminar_acentos(item)

# %% [markdown]
# Eliminar comillas simples y dobles

# %%
for i, item in enumerate(data.cast):
    if item.find("'") != -1:
        item = item.replace("'","")
        data.cast.iloc[i] = item
    if item.find('"') != -1:
        item = item.replace('"','')
        data.cast.iloc[i] = item

# %% [markdown]
# ## Crear tabla Actor

# %%
list_actor = []

for item in data.cast:
    for actor in item.split(','):
        list_actor.append(actor)

# %%
for i, item in enumerate(list_actor):
    item = item.rstrip()
    item = item.lstrip()
    list_actor[i] = item
    
list_actor = set(list_actor)
list_actor = list(list_actor)

# %%
Actor = pd.DataFrame({'IdActor': list(range(1,len(list_actor)+1)), 'Name': list_actor})
Actor
# Out:
#        IdActor             Name
# 0            1  Walker Edmiston
# 1            2  Richard Widmark
# 2            3
# 3            4     Gordon Clapp
# 4            5   Indra Chandran
# ...        ...              ...
# 62243    62244       Otto Sirgo
# 62244    62245    Derek Losoncy
# 62245    62246        Noah Reid
# 62246    62247      Ben Whishaw
# 62247    62248  Candy Tolentino
#
# [62248 rows x 2 columns]

# %%
Actor.to_csv('./Tablas/Actor.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Genr

# %%
list_genr = []

for item in data.listed_in:
    for genr in item.split(','):
        list_genr.append(genr)

# %%
for i, item in enumerate(list_genr):
    item = item.rstrip()
    item = item.lstrip()
    list_genr[i] = item
    
list_genr = set(list_genr)
list_genr = list(list_genr)

# %%
Genr = pd.DataFrame({'IdGenr': list(range(1,len(list_genr)+1)), 'Genr': list_genr})
Genr
# Out:
#      IdGenr                       Genr
# 0         1                      Crime
# 1         2            Science Fiction
# 2         3             Crime TV Shows
# 3         4                       Arts
# 4         5                     Horror
# ..      ...                        ...
# 115     116             Cooking & Food
# 116     117  Spanish-Language TV Shows
# 117     118            Romantic Comedy
# 118     119           Animals & Nature
# 119     120              Sketch Comedy
#
# [120 rows x 2 columns]

# %%
Genr.to_csv('./Tablas/Genr.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Creamos tabla Movie

# %%
Movie = pd.DataFrame(columns=['IdMovie', 'Title', 'IdType','IdPlatform', 
                              'ReleaseYear', 'Duration', 'TimeUnit'])
Movie
# Out:
# Empty DataFrame
# Columns: [IdMovie, Title, IdType, IdPlatform, ReleaseYear, Duration, TimeUnit]
# Index: []

# %% [markdown]
# Eliminamos comillas simples y dobles de la columna 'title'

# %%
for i, item in enumerate(data.title):
    if item.find("'") != -1:
        item = item.replace("'","")
        data.title.iloc[i] = item
    if item.find('"') != -1:
        item = item.replace('"','')
        data.title.iloc[i] = item
# Out:
# C:\Users\Hermann\Anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
for i in range(data.shape[0]):
    
    if data.type.iloc[i] == 'Movie':
        type_ = 1 
    elif data.type.iloc[i] == 'TV Show':
        type_ = 2
        
    if data.platform.iloc[i] == 'Amazon':
        platform = 1
    elif data.platform.iloc[i] == 'Disney':
        platform = 2
    elif data.platform.iloc[i] == 'Hulu':
        platform = 3
    elif data.platform.iloc[i] == 'Netflix':
        platform = 4
        
    aux = data.duration.iloc[i].split(' ')
    
    if aux[0] == 'No' and aux[1] == 'Info':
        duration = np.nan
        time_unit = 'No Info'
    else:
        duration = int(aux[0])
        if aux[1] == 'min':
            time_unit = 'min'
        elif aux[1] == 'Season' or aux[1] == 'Seasons':
            time_unit = 'season'
        
    Movie = Movie.append({'IdMovie': i+1, 
                          'Title': data.title.iloc[i], 
                          'IdType': type_,
                          'IdPlatform': platform, 
                          'ReleaseYear': data.release_year.iloc[i], 
                          'Duration': duration, 
                          'TimeUnit': time_unit},
                         ignore_index=True)

# %%
Movie
# Out:
#       IdMovie                 Title IdType IdPlatform ReleaseYear Duration  \
# 0           1   The Grand Seduction      1          1        2014      113
# 1           2  Take Care Good Night      1          1        2018      110
# 2           3  Secrets of Deception      1          1        2017       74
# 3           4    Pink: Staying True      1          1        2014       69
# 4           5         Monster Maker      1          1        1989       45
# ...       ...                   ...    ...        ...         ...      ...
# 22993   22994                Zodiac      1          4        2007      158
# 22994   22995           Zombie Dumb      2          4        2018        2
# 22995   22996            Zombieland      1          4        2009       88
# 22996   22997                  Zoom      1          4        2006       88
# 22997   22998                Zubaan      1          4        2015      111
#
#       TimeUnit
# 0          min
# 1          min
# 2          min
# ...

# %%
Movie.to_csv('./Tablas/Movie.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Tablas auxiliares

# %% [markdown]
# ### Tabla Movie_Actor

# %%
IdMovieActor = []
IdActor = []

for i in range(data.shape[0]):
    actors = data.cast.iloc[i].split(',')
    for j in range(len(actors)):
        actor = actors[j]
        actor = actor.rstrip()
        actor = actor.lstrip()
        index = list_actor.index(actor)
        IdMovieActor.append(i+1)
        IdActor.append(index+1)

# %%
Movie_Actor = pd.DataFrame({'IdMovie': IdMovieActor, 'IdActor':IdActor})  
Movie_Actor
# Out:
#         IdMovie  IdActor
# 0             1    48068
# 1             1    49592
# 2             1     8756
# 3             2    33734
# 4             2    18881
# ...         ...      ...
# 122244    22998    54410
# 122245    22998    47995
# 122246    22998    57599
# 122247    22998    40506
# 122248    22998     3141
#
# [122249 rows x 2 columns]

# %%
Movie_Actor.to_csv('./Tablas/Movie_Actor.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Tabla Movie_Genr

# %%
IdMovieGenr = []
IdGenr = []

for i in range(data.shape[0]):
    for j in range(Genr.shape[0]):
        if data.listed_in.iloc[i].find(Genr.Genr.iloc[j]) != -1:
            IdMovieGenr.append(Movie.IdMovie.iloc[i])
            IdGenr.append(Genr.IdGenr.iloc[j])

# %%
Movie_Genr = pd.DataFrame({'IdMovie': IdMovieGenr, 'IdGenr':IdGenr})  
Movie_Genr
# Out:
#        IdMovie  IdGenr
# 0            1      79
# 1            1     110
# 2            2       7
# 3            2      79
# 4            3      21
# ...        ...     ...
# 72152    22998      50
# 72153    22998      79
# 72154    22998      80
# 72155    22998      82
# 72156    22998      96
#
# [72157 rows x 2 columns]

# %%
Movie_Genr.to_csv('./Tablas/Movie_Genr.csv', index=False, encoding='utf-8')
